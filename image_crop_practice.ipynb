# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow

# %% [markdown]
# #파일 로드

# %%
(train_x, train_y),(test_x, test_y) = tensorflow.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
ㅋ

# %%
print(image.shape)
# Out:
# (28, 28)

# %%
cropped = image[5:20,5:20]
plt.imshow(cropped, cmap="binary")
plt.show()

# %% [markdown]
# #이미지 저장

# %%
plt.imsave("cropped_mnist.jpg",cropped)

# %% [markdown]
# #이미지 로드

# %%
loaded = plt.imread("cropped_mnist.jpg")
print(loaded.shape)
plt.imshow(loaded)
plt.show()
# Out:
# (15, 15, 3)

# %% [markdown]
# # 파일로 저장

# %%
np.save("crooped.npy", cropped)

# %% [markdown]
# #넘파이로 저장

# %%
loaded = np.load("crooped.npy")
print(loaded.shape)
plt.imshow(loaded, cmap="binary")
plt.show()
# Out:
# (15, 15)

# %% [markdown]
# #컬러 영상 로드

# %%
(train_x, train_y), (test_x, test_y) = tensorflow.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
image = train_x[77]
plt.imshow(image)
plt.show()

# %%
print(image.shape)
# Out:
# (32, 32, 3)

# %%
cropped = image[9:25,1:30, :]
plt.imshow(cropped)
plt.show()

# %% [markdown]
# #이미지 저장

# %%
plt.imsave("cropped.jpg",cropped)

# %% [markdown]
# #이미지 로드

# %%
loaded = plt.imread("cropped.jpg")
print(loaded.shape)
plt.imshow(loaded)
plt.show()
# Out:
# (16, 29, 3)

# %% [markdown]
# #업로드한 이미지

# %%
image = plt.imread("iu.jpg")
print(image.shape)
plt.imshow(image)
plt.show()
# Out:
# (743, 610, 3)

# %%
cropped = image[0:200, 270:400, :]
plt.imshow(cropped)
plt.show()

# %% [markdown]
# #파일로 저장/읽기

# %%
plt.imsave("iu_cropped.jpg",cropped)

# %%
loaded = plt.imread("iu_cropped.jpg")
print(loaded.shape)
plt.imshow(loaded)
plt.show()
# Out:
# (200, 130, 3)

# %% [markdown]
# #이미지 리사이즈

# %%
import cv2

resized = cv2.resize(cropped, dsize=(224,224))
plt.imshow(resized)
plt.show()

print(cropped.shape)
print(resized.shape)
# Out:
# (200, 130, 3)
# (224, 224, 3)
